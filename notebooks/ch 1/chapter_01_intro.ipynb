# %% [markdown]
# # Machine Learning Refined - Chapter 1
# ## Goal
# Establish a foundational understanding of the machine learning paradigm
#
# ## Notes
# - [ ] Read the introduction.
# - [ ] Define the cost function
# - [ ] Experiment with simple gradient descent
